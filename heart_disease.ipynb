# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("heart_disease.csv")
df
# Out:
#      63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0    44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1    60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2    55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3    66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4    66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0
# ..   .. .. ..  ...  ... ..  ...  ...  ..   ... .. ..  ..  ...
# 194  54  0  4  127  333  1    1  154   0     0  ?  ?   ?    1
# 195  62  1  1    ?  139  0    1    ?   ?     ?  ?  ?   ?    0
# 196  55  1  4  122  223  1    1  100   0     0  ?  ?   6    2
# 197  58  1  4    ?  385  1    2    ?   ?     ?  ?  ?   ?    0
# 198  62  1  2  120  254  0    2   93   1     0  ?  ?   ?    1
#
# [199 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# 63     0
# 1      0
# 4      0
# 140    0
# 260    0
# 0      0
# 1.1    0
# 112    0
# 1.2    0
# 3      0
# 2      0
# ?      0
# ?.1    0
# 2.1    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['63', '1', '4', '140', '260', '0', '1.1', '112', '1.2', '3', '2', '?',
#        '?.1', '2.1'],
#       dtype='object')

# %%
df = df.rename(columns={'63' : 'Age','1' : 'Sex','4' :'cp','140':'testbps','260':'chol','0':'fbs','1.1':'restecg','112':'thalach','1.2':'exang','3':'oldpeak','2':'slope','?':'CA','?.1':'thal','2.1':'num'})

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'testbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'CA', 'thal', 'num'],
#       dtype='object')

# %%
df
# Out:
#      Age  Sex  cp testbps chol fbs  restecg thalach exang oldpeak slope CA  \
# 0     44    1   4     130  209   0        1     127     0       0     ?  ?
# 1     60    1   4     132  218   0        1     140     1     1.5     3  ?
# 2     55    1   4     142  228   0        1     149     1     2.5     1  ?
# 3     66    1   3     110  213   1        2      99     1     1.3     2  ?
# 4     66    1   3     120    0   0        1     120     0    -0.5     1  ?
# ..   ...  ...  ..     ...  ...  ..      ...     ...   ...     ...   ... ..
# 194   54    0   4     127  333   1        1     154     0       0     ?  ?
# 195   62    1   1       ?  139   0        1       ?     ?       ?     ?  ?
# 196   55    1   4     122  223   1        1     100     0       0     ?  ?
# 197   58    1   4       ?  385   1        2       ?     ?       ?     ?  ?
# 198   62    1   2     120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    0
# 1      ?    2
# 2      ?    1
# ...

# %%
df.isnull().sum()
# Out:
# Age        0
# Sex        0
# cp         0
# testbps    0
# chol       0
# fbs        0
# restecg    0
# thalach    0
# exang      0
# oldpeak    0
# slope      0
# CA         0
# thal       0
# num        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      199 non-null    int64
#  1   Sex      199 non-null    int64
#  2   cp       199 non-null    int64
#  3   testbps  199 non-null    object
#  4   chol     199 non-null    object
#  5   fbs      199 non-null    object
#  6   restecg  199 non-null    int64
#  7   thalach  199 non-null    object
#  8   exang    199 non-null    object
#  9   oldpeak  199 non-null    object
#  10  slope    199 non-null    object
#  11  CA       199 non-null    object
#  12  thal     199 non-null    object
#  13  num      199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df['testbps']
# Out:
# 0      130
# 1      132
# 2      142
# 3      110
# 4      120
#       ...
# 194    127
# 195      ?
# 196    122
# 197      ?
# 198    120
# Name: testbps, Length: 199, dtype: object

# %%
df=df.replace('?',np.NaN)

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# cp           0
# testbps     56
# chol         7
# fbs          7
# restecg      0
# thalach     53
# exang       53
# oldpeak     56
# slope      102
# CA         197
# thal       165
# num          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      199 non-null    int64
#  1   Sex      199 non-null    int64
#  2   cp       199 non-null    int64
#  3   testbps  143 non-null    object
#  4   chol     192 non-null    object
#  5   fbs      192 non-null    object
#  6   restecg  199 non-null    int64
#  7   thalach  146 non-null    object
#  8   exang    146 non-null    object
#  9   oldpeak  143 non-null    object
#  10  slope    97 non-null     object
#  11  CA       2 non-null      object
#  12  thal     34 non-null     object
#  13  num      199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df = df.apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      199 non-null    int64
#  1   Sex      199 non-null    int64
#  2   cp       199 non-null    int64
#  3   testbps  143 non-null    float64
#  4   chol     192 non-null    float64
#  5   fbs      192 non-null    float64
#  6   restecg  199 non-null    int64
#  7   thalach  146 non-null    float64
#  8   exang    146 non-null    float64
#  9   oldpeak  143 non-null    float64
#  10  slope    97 non-null     float64
#  11  CA       2 non-null      float64
#  12  thal     34 non-null     float64
#  13  num      199 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 21.9 KB

# %%
df['chol'].fillna(df['chol'].mean(),inplace=True)

# %%
df['fbs'].fillna(df['fbs'].mean(),inplace=True)

# %%
df['testbps'].fillna(df['testbps'].median(),inplace=True)

# %%
df['thalach'].fillna(df['thalach'].median(),inplace=True)

# %%
df['exang'].fillna(df['exang'].median(),inplace=True)

# %%
df['oldpeak'].fillna(df['oldpeak'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# cp           0
# testbps      0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope      102
# CA         197
# thal       165
# num          0
# dtype: int64

# %%
df_new = df.dropna(axis=1)

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (199, 14)
# (199, 11)

# %%
df_new.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'testbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'num'],
#       dtype='object')

# %%
df_new.isnull().sum()
# Out:
# Age        0
# Sex        0
# cp         0
# testbps    0
# chol       0
# fbs        0
# restecg    0
# thalach    0
# exang      0
# oldpeak    0
# num        0
# dtype: int64

# %%
df_new
# Out:
#      Age  Sex  cp  testbps   chol  fbs  restecg  thalach  exang  oldpeak  num
# 0     44    1   4    130.0  209.0  0.0        1    127.0    0.0      0.0    0
# 1     60    1   4    132.0  218.0  0.0        1    140.0    1.0      1.5    2
# 2     55    1   4    142.0  228.0  0.0        1    149.0    1.0      2.5    1
# 3     66    1   3    110.0  213.0  1.0        2     99.0    1.0      1.3    0
# 4     66    1   3    120.0    0.0  0.0        1    120.0    0.0     -0.5    0
# ..   ...  ...  ..      ...    ...  ...      ...      ...    ...      ...  ...
# 194   54    0   4    127.0  333.0  1.0        1    154.0    0.0      0.0    1
# 195   62    1   1    130.0  139.0  0.0        1    120.0    1.0      1.5    0
# 196   55    1   4    122.0  223.0  1.0        1    100.0    0.0      0.0    2
# 197   58    1   4    130.0  385.0  1.0        2    120.0    1.0      1.5    0
# 198   62    1   2    120.0  254.0  0.0        2     93.0    1.0      0.0    1
#
# [199 rows x 11 columns]

# %%
df_new.describe()
# Out:
#               Age         Sex          cp     testbps        chol         fbs  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513  132.673367  178.322917    0.354167
# std      7.827080    0.171433    0.796928   18.374852  112.144792    0.470958
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  125.500000  119.500000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  214.000000    0.000000
# 75%     64.000000    1.000000    4.000000  140.000000  254.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak         num
# count  199.000000  199.000000  199.000000  199.000000  199.000000
# mean     0.733668  122.105528    0.738693    1.362814    1.517588
# std      0.684918   18.910312    0.440455    0.936426    1.222038
# ...

# %% [markdown]
# EDA

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.countplot(x='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='Age',data=df_new)

# %%
sns.countplot(x='Sex',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='cp',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='testbps',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='chol',data=df_new)

# %%
sns.countplot(x='fbs',data=df_new)

# %%
sns.countplot(x='restecg',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='thalach',data=df_new)

# %%
sns.countplot(x='exang',data=df_new)

# %%
sns.countplot(x='oldpeak',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Age',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Sex',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='cp',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='testbps',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='chol',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='fbs',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='restecg',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='thalach',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='exang',y='num',data=df_new)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='oldpeak',y='num',data=df_new)

# %%
sns.pairplot(df_new)

# %%
df_new.skew()
# Out:
# Age       -0.397178
# Sex       -5.537073
# cp        -1.641267
# testbps   -1.312745
# chol      -0.563256
# fbs        0.625593
# restecg    0.396540
# thalach    0.258275
# exang     -1.094854
# oldpeak    0.264024
# num        0.302681
# dtype: float64

# %%
for col in df_new.columns:
    if df_new[col].skew()>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
df_new.skew()
# Out:
# Age       -0.397178
# Sex       -5.537073
# cp        -1.641267
# testbps   -1.312745
# chol      -0.563256
# fbs        0.605960
# restecg    0.396540
# thalach    0.258275
# exang     -1.094854
# oldpeak    0.264024
# num        0.302681
# dtype: float64

# %% [markdown]
# outliers

# %%
df_new.plot(kind='box',subplots='true',layout=(3,5),figsize=(20,15))
# Out:
# Age           AxesSubplot(0.125,0.657941;0.133621x0.222059)
# Sex        AxesSubplot(0.285345,0.657941;0.133621x0.222059)
# cp          AxesSubplot(0.44569,0.657941;0.133621x0.222059)
# testbps    AxesSubplot(0.606034,0.657941;0.133621x0.222059)
# chol       AxesSubplot(0.766379,0.657941;0.133621x0.222059)
# fbs           AxesSubplot(0.125,0.391471;0.133621x0.222059)
# restecg    AxesSubplot(0.285345,0.391471;0.133621x0.222059)
# thalach     AxesSubplot(0.44569,0.391471;0.133621x0.222059)
# exang      AxesSubplot(0.606034,0.391471;0.133621x0.222059)
# oldpeak    AxesSubplot(0.766379,0.391471;0.133621x0.222059)
# num              AxesSubplot(0.125,0.125;0.133621x0.222059)
# dtype: object

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df_new))


threshold=3
new_df=df_new[(z<3).all(axis=1)]

# %%
print("original shape=",df_new.shape,"\n New shape= ",new_df.shape)
# Out:
# original shape= (199, 11)
#  New shape=  (180, 11)

# %%
new_df.plot(kind='box',subplots='true',layout=(3,5),figsize=(20,15))
# Out:
# Age           AxesSubplot(0.125,0.657941;0.133621x0.222059)
# Sex        AxesSubplot(0.285345,0.657941;0.133621x0.222059)
# cp          AxesSubplot(0.44569,0.657941;0.133621x0.222059)
# testbps    AxesSubplot(0.606034,0.657941;0.133621x0.222059)
# chol       AxesSubplot(0.766379,0.657941;0.133621x0.222059)
# fbs           AxesSubplot(0.125,0.391471;0.133621x0.222059)
# restecg    AxesSubplot(0.285345,0.391471;0.133621x0.222059)
# thalach     AxesSubplot(0.44569,0.391471;0.133621x0.222059)
# exang      AxesSubplot(0.606034,0.391471;0.133621x0.222059)
# oldpeak    AxesSubplot(0.766379,0.391471;0.133621x0.222059)
# num              AxesSubplot(0.125,0.125;0.133621x0.222059)
# dtype: object

# %% [markdown]
# Checking Correlation

# %%
corr=df_new.corr()

# %%
plt.figure(figsize=(30,20))
sns.heatmap(corr,annot=True)
plt.show()

# %%
df_new1=df_new#.drop(['fbs','Sex'],axis=1)

# %% [markdown]
# Model training

# %%
x_train=df_new1.drop(columns=['num'])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x_train)
x=pd.DataFrame(x,columns=x_train.columns)
y=df_new1['num']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=33)

# %%
print(x_train.shape,'\t',x_test.shape)
# Out:
# (149, 10) 	 (50, 10)

# %%
print(y_train.shape,'\t',y_test.shape)
# Out:
# (149,) 	 (50,)

# %%
import pandas as pd
import seaborn as sb
import numpy as np
from sklearn.model_selection import train_test_split




from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.3
# [[3 7 4 1 0]
#  [5 5 1 2 0]
#  [2 2 6 1 1]
#  [2 3 0 1 2]
#  [0 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.25      0.20      0.22        15
#            1       0.29      0.38      0.33        13
#            2       0.50      0.50      0.50        12
#            3       0.17      0.12      0.14         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.30        50
#    macro avg       0.24      0.24      0.24        50
# weighted avg       0.30      0.30      0.30        50

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.44
# [[10  3  2  0  0]
#  [ 2 10  1  0  0]
#  [ 4  3  2  3  0]
#  [ 1  3  3  0  1]
#  [ 0  0  1  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.67      0.62        15
#            1       0.53      0.77      0.62        13
#            2       0.22      0.17      0.19        12
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.44        50
#    macro avg       0.27      0.32      0.29        50
# weighted avg       0.37      0.44      0.40        50

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.36
# [[8 3 2 2 0]
#  [4 7 2 0 0]
#  [1 5 2 4 0]
#  [1 4 2 1 0]
#  [0 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.53      0.55        15
#            1       0.37      0.54      0.44        13
#            2       0.22      0.17      0.19        12
#            3       0.12      0.12      0.12         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.36        50
#    macro avg       0.26      0.27      0.26        50
# weighted avg       0.34      0.36      0.34        50

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.28
# [[ 3 10  1  1  0]
#  [ 2 11  0  0  0]
#  [ 1  9  0  2  0]
#  [ 0  7  0  0  1]
#  [ 0  0  1  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29        15
#            1       0.30      0.85      0.44        13
#            2       0.00      0.00      0.00        12
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.28        50
#    macro avg       0.16      0.21      0.15        50
# weighted avg       0.23      0.28      0.20        50

# %%
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.34
# [[8 5 2 0 0]
#  [6 5 1 1 0]
#  [1 3 3 5 0]
#  [1 3 1 1 2]
#  [0 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.52        15
#            1       0.31      0.38      0.34        13
#            2       0.38      0.25      0.30        12
#            3       0.12      0.12      0.12         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.34        50
#    macro avg       0.26      0.26      0.26        50
# weighted avg       0.34      0.34      0.34        50

# %%
from sklearn.ensemble import AdaBoostClassifier

ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=rf.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# 0.34
# [[8 5 2 0 0]
#  [6 5 1 1 0]
#  [1 3 3 5 0]
#  [1 3 1 1 2]
#  [0 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.52        15
#            1       0.31      0.38      0.34        13
#            2       0.38      0.25      0.30        12
#            3       0.12      0.12      0.12         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.34        50
#    macro avg       0.26      0.26      0.26        50
# weighted avg       0.34      0.34      0.34        50

# %%
from sklearn.svm import SVC
svc=SVC()

ad=AdaBoostClassifier(n_estimators=50,base_estimator=svc,algorithm='SAMME')
ad.fit(x_train,y_train)
predad=rf.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# 0.34
# [[8 5 2 0 0]
#  [6 5 1 1 0]
#  [1 3 3 5 0]
#  [1 3 1 1 2]
#  [0 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.52        15
#            1       0.31      0.38      0.34        13
#            2       0.38      0.25      0.30        12
#            3       0.12      0.12      0.12         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.34        50
#    macro avg       0.26      0.26      0.26        50
# weighted avg       0.34      0.34      0.34        50

# %%
from sklearn.svm import SVC
svc=SVC(probability=True, kernel='linear')

ad=AdaBoostClassifier(n_estimators=50,base_estimator=svc)
ad.fit(x_train,y_train)
predad=rf.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# 0.34
# [[8 5 2 0 0]
#  [6 5 1 1 0]
#  [1 3 3 5 0]
#  [1 3 1 1 2]
#  [0 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.52        15
#            1       0.31      0.38      0.34        13
#            2       0.38      0.25      0.30        12
#            3       0.12      0.12      0.12         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.34        50
#    macro avg       0.26      0.26      0.26        50
# weighted avg       0.34      0.34      0.34        50

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
estimator_KNN = KNeighborsClassifier(algorithm='auto')
parameters_KNN = {
    'n_neighbors': (1,10, 1),
    'leaf_size': (20,40,1),
    'p': (1,2),
    'weights': ('uniform', 'distance'),
    'metric': ('minkowski', 'chebyshev'),}

# with GridSearch
gd_sr = GridSearchCV(
    estimator=estimator_KNN,
    param_grid=parameters_KNN,
    scoring = 'accuracy',
    n_jobs = -1,
    cv = 5
)

    
gd_sr.fit(x_train,y_train)

best_parameters = gd_sr.best_params_
print(best_parameters)
best_result= gd_sr.best_score_
print(best_result)
# Out:
# {'leaf_size': 20, 'metric': 'minkowski', 'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}
# 0.375632183908046

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)

accu=accuracy_score(y_test,predknn)
print("accuracy score = ",accu*100)
# Out:
# accuracy score =  44.0

# %%
from sklearn.model_selection import cross_val_score

score=cross_val_score(knn,x,y,cv=10,scoring='accuracy').mean()
print("Score:" ,score*100)
print("Mean score :", score.mean())
print("standard deviation :", score.std())
# Out:
# Score: 40.15789473684211
# Mean score : 0.4015789473684211
# standard deviation : 0.0

# %%
import pickle

filename = 'pickledtcfile.pkl'
pickle.dump(knn, open(filename,'wb'))

loaded_model = pickle.load(open(filename,'rb'))

loaded_model.predict(x)
# Out:
# array([0, 2, 1, 0, 0, 3, 0, 0, 1, 0, 1, 1, 1, 2, 0, 2, 1, 2, 2, 1, 2, 1,
#        0, 0, 2, 1, 1, 1, 0, 1, 3, 3, 1, 0, 1, 2, 1, 1, 0, 3, 1, 2, 0, 3,
#        1, 1, 0, 0, 0, 0, 0, 2, 0, 0, 0, 1, 3, 0, 3, 0, 1, 1, 1, 2, 2, 3,
#        1, 0, 1, 0, 2, 0, 1, 3, 1, 0, 1, 1, 0, 3, 2, 3, 2, 3, 0, 3, 1, 1,
#        1, 3, 0, 1, 1, 1, 3, 0, 1, 0, 2, 1, 2, 1, 1, 0, 4, 1, 1, 0, 1, 3,
#        1, 0, 3, 1, 3, 1, 2, 2, 1, 2, 0, 1, 0, 0, 4, 1, 2, 0, 2, 0, 1, 2,
#        0, 2, 0, 1, 3, 0, 2, 2, 1, 0, 4, 0, 0, 2, 4, 1, 2, 0, 3, 1, 1, 2,
#        1, 2, 2, 3, 1, 2, 1, 2, 3, 0, 0, 3, 3, 3, 1, 1, 0, 3, 1, 0, 0, 3,
#        1, 3, 1, 0, 0, 2, 1, 2, 1, 1, 2, 3, 1, 0, 3, 1, 2, 0, 1, 0, 0, 0,
#        0])
