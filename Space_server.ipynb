# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("space_server.csv")
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
df.shape
# Out:
# (10000, 18)

# %%
df_new=df.dropna()

# %%
df_new.fillna(df_new.median(), inplace=True)

# %%
df_new = df_new.reset_index()

# %%
df_new.shape
# Out:
# (10000, 19)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      10000 non-null  int64
#  1   objid      10000 non-null  float64
#  2   ra         10000 non-null  float64
#  3   dec        10000 non-null  float64
#  4   u          10000 non-null  float64
#  5   g          10000 non-null  float64
#  6   r          10000 non-null  float64
#  7   i          10000 non-null  float64
#  8   z          10000 non-null  float64
#  9   run        10000 non-null  int64
#  10  rerun      10000 non-null  int64
#  11  camcol     10000 non-null  int64
#  12  field      10000 non-null  int64
#  13  specobjid  10000 non-null  float64
#  14  class      10000 non-null  object
#  15  redshift   10000 non-null  float64
#  16  plate      10000 non-null  int64
#  17  mjd        10000 non-null  int64
#  18  fiberid    10000 non-null  int64
# ...

# %%
df_new.isnull().sum()
# Out:
# index        0
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
df_new['rerun'].unique()
# Out:
# array([301])

# %%
df_new['class'].unique()
# Out:
# array(['STAR', 'GALAXY', 'QSO'], dtype=object)

# %%
values1 = {'STAR':0, 'GALAXY':1,'QSO':2}
df_new['class'] = df_new['class'].apply(lambda e: values1[e])
df_new['class'] = pd.to_numeric(df_new['class'])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      10000 non-null  int64
#  1   objid      10000 non-null  float64
#  2   ra         10000 non-null  float64
#  3   dec        10000 non-null  float64
#  4   u          10000 non-null  float64
#  5   g          10000 non-null  float64
#  6   r          10000 non-null  float64
#  7   i          10000 non-null  float64
#  8   z          10000 non-null  float64
#  9   run        10000 non-null  int64
#  10  rerun      10000 non-null  int64
#  11  camcol     10000 non-null  int64
#  12  field      10000 non-null  int64
#  13  specobjid  10000 non-null  float64
#  14  class      10000 non-null  int64
#  15  redshift   10000 non-null  float64
#  16  plate      10000 non-null  int64
#  17  mjd        10000 non-null  int64
#  18  fiberid    10000 non-null  int64
# ...

# %%
df_new.shape
# Out:
# (10000, 19)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.barplot(x='class',y='objid',data=df_new)

# %%
sns.barplot(x='class',y='ra',data=df_new)

# %%
sns.barplot(x='class',y='dec',data=df_new)

# %%
sns.barplot(x='class',y='u',data=df_new)

# %%
sns.barplot(x='class',y='g',data=df_new)

# %%
sns.barplot(x='class',y='r',data=df_new)

# %%
sns.barplot(x='class',y='i',data=df_new)

# %%
sns.barplot(x='class',y='z',data=df_new)

# %%
sns.barplot(x='class',y='run',data=df_new)

# %%
sns.barplot(x='class',y='rerun',data=df_new)

# %%
sns.barplot(x='class',y='camcol',data=df_new)

# %%
sns.barplot(x='class',y='field',data=df_new)

# %%
sns.barplot(x='class',y='specobjid',data=df_new)

# %%
sns.barplot(x='class',y='redshift',data=df_new)

# %%
sns.barplot(x='class',y='plate',data=df_new)

# %%
sns.barplot(x='class',y='mjd',data=df_new)

# %%
sns.barplot(x='class',y='fiberid',data=df_new)

# %%
df_new.skew()
# Out:
# index        0.000000
# objid        1.000150
# ra          -1.227350
# dec          1.191544
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# rerun        0.000000
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# class        0.381391
# redshift     4.265729
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %%
for col in df_new.columns:
    if df_new[col].skew()>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
df_new.skew()
# Out:
# index        0.000000
# objid        1.000150
# ra          -1.227350
# dec          0.152301
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# rerun        0.000000
# camcol      -0.100220
# field        0.249795
# specobjid    0.696181
# class        0.381391
# redshift     3.513844
# plate        0.696680
# mjd          1.011097
# fiberid      0.308053
# dtype: float64

# %%
df_new.plot(kind='box',subplots='true',layout=(5,5),figsize=(20,15))
# Out:
# index           AxesSubplot(0.125,0.749828;0.133621x0.130172)
# objid        AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# ra            AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# dec          AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# u            AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# g               AxesSubplot(0.125,0.593621;0.133621x0.130172)
# r            AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# i             AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# z            AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# run          AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# rerun           AxesSubplot(0.125,0.437414;0.133621x0.130172)
# camcol       AxesSubplot(0.285345,0.437414;0.133621x0.130172)
# field         AxesSubplot(0.44569,0.437414;0.133621x0.130172)
# specobjid    AxesSubplot(0.606034,0.437414;0.133621x0.130172)
# class        AxesSubplot(0.766379,0.437414;0.133621x0.130172)
# ...

# %% [markdown]
# We cannot remove outliers

# %%
corr1=df_new.corr()

# %%
corr1
# Out:
#               index         objid            ra           dec             u  \
# index      1.000000  0.000000e+00  9.469459e-02  4.068930e-01  1.985301e-02
# objid      0.000000  1.000000e+00  2.524419e-14  6.587931e-18  5.581214e-14
# ra         0.094695  2.524419e-14  1.000000e+00 -1.875583e-01  3.123756e-02
# dec        0.406893  6.587931e-18 -1.875583e-01  1.000000e+00  3.089078e-02
# u          0.019853  5.581214e-14  3.123756e-02  3.089078e-02  1.000000e+00
# g          0.025613  1.001149e-13  4.390863e-02  5.248748e-02  8.492320e-01
# r          0.025554  2.995673e-14  4.710290e-02  5.158034e-02  6.923790e-01
# i          0.025002  2.212198e-14  4.573107e-02  4.618115e-02  6.026302e-01
# z          0.025020 -4.107700e-14  4.294957e-02  4.432558e-02  5.514828e-01
# run        0.400105 -1.553011e-14 -9.274056e-02  8.208198e-01  3.822910e-02
# rerun           NaN           NaN           NaN           NaN           NaN
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(corr1,annot=True)
plt.show()

# %%
df_new.drop(['rerun'],axis=1,inplace=True)

# %%
corr=df_new.corr()

# %%
plt.figure(figsize=(30,20))
sns.heatmap(corr,annot=True)
plt.show()

# %%
import pandas as pd
import seaborn as sb
import numpy as np
from sklearn.model_selection import train_test_split



from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
df_new
# Out:
#       index         objid          ra       dec         u         g         r  \
# 0         0  1.237650e+18  183.531326  0.085896  19.47406  17.04240  15.94699
# 1         1  1.237650e+18  183.598371  0.126884  18.66280  17.21449  16.67637
# 2         2  1.237650e+18  183.680207  0.118836  19.38298  18.19169  17.47428
# 3         3  1.237650e+18  183.870529  0.048705  17.76536  16.60272  16.16116
# 4         4  1.237650e+18  183.883288  0.097632  17.55025  16.26342  16.43869
# ...     ...           ...         ...       ...       ...       ...       ...
# 9995   9995  1.237650e+18  131.316413  3.961566  18.81777  17.47053  16.91508
# 9996   9996  1.237650e+18  131.306083  3.964071  18.27255  17.43849  17.07692
# 9997   9997  1.237650e+18  131.552562  3.963989  18.75818  17.77784  17.51872
# 9998   9998  1.237650e+18  131.477151  3.965622  18.88287  17.91068  17.53152
# 9999   9999  1.237650e+18  131.665012  3.966612  19.27586  17.37829  16.30542
#
# ...

# %%
import pandas as pd

def clean_dataset(df_new):
    assert isinstance(df_new, pd.DataFrame), "df_new needs to be a pd.DataFrame"
    df_new.dropna(inplace=True)
    indices_to_keep = ~df_new.isin([np.nan, np.inf, -np.inf]).any(1)
    return df_new[indices_to_keep].astype(np.float64)

# %% [markdown]
# Model training

# %%
from sklearn.preprocessing import StandardScaler

x1=clean_dataset(df_new)
x2=x1.drop(columns=['class'])

sc=StandardScaler()
x=sc.fit_transform(x2)
x=pd.DataFrame(x,columns=x2.columns)
y=df_new['class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=45)
y_test = y_test.astype('int64')

# %%
print(x_train.shape,'\t',x_test.shape)
# Out:
# (7064, 17) 	 (1766, 17)

# %%
print(y_train.shape,'\t',y_test.shape)
# Out:
# (7064,) 	 (1766,)

# %%
import pandas as pd
import seaborn as sb
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import utils


from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
print(training_scores_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))


print(utils.multiclass.type_of_target(training_scores_encoded))
# Out:
# [0 1 2 ... 0 1 0]
# multiclass
# multiclass
# multiclass

# %%
import warnings
warnings.filterwarnings("ignore")
from warnings import simplefilter
simplefilter(action='ignore',category=FutureWarning)


dtc = DecisionTreeClassifier()
dtc.fit(x_train,training_scores_encoded)
dtc.score(x_train,training_scores_encoded)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9886749716874292
# [[725   0   0]
#  [  3 877   7]
#  [  1   9 144]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       725
#            1       0.99      0.99      0.99       887
#            2       0.95      0.94      0.94       154
#
#     accuracy                           0.99      1766
#    macro avg       0.98      0.97      0.98      1766
# weighted avg       0.99      0.99      0.99      1766

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,training_scores_encoded)
knn.score(x_train,training_scores_encoded)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.905436013590034
# [[632  93   0]
#  [ 54 831   2]
#  [  5  13 136]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       725
#            1       0.89      0.94      0.91       887
#            2       0.99      0.88      0.93       154
#
#     accuracy                           0.91      1766
#    macro avg       0.93      0.90      0.91      1766
# weighted avg       0.91      0.91      0.91      1766

# %%
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,training_scores_encoded)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.9869762174405436
# [[724   1   0]
#  [  8 874   5]
#  [  1   8 145]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       725
#            1       0.99      0.99      0.99       887
#            2       0.97      0.94      0.95       154
#
#     accuracy                           0.99      1766
#    macro avg       0.98      0.98      0.98      1766
# weighted avg       0.99      0.99      0.99      1766

# %%
#cross validation 
from sklearn.model_selection import cross_val_score






models=[rf,knn,dtc]
for m in models:
    score=cross_val_score(m,x_train,training_scores_encoded,cv=10,scoring='accuracy')
    print("model :",m)
    print("score :",score)
    print("Mean score :",score.mean())
    print("standard deviation :",score.std())
    print("**********************************************************")
    print('\n')
# Out:
# model : RandomForestClassifier(random_state=42)
# score : [0.99151344 0.98868458 0.99009901 0.98727016 0.9815864  0.98300283
#  0.99291785 0.99008499 0.99150142 0.99433428]
# Mean score : 0.9890994947329617
# standard deviation : 0.003907477611508183
# **********************************************************
#
#
# model : KNeighborsClassifier()
# score : [0.9009901  0.91089109 0.90806223 0.90523338 0.90509915 0.89518414
#  0.90651558 0.92067989 0.88810198 0.91359773]
# Mean score : 0.9054355273649584
# standard deviation : 0.008730979306335864
# **********************************************************
#
#
# model : DecisionTreeClassifier()
# score : [0.98302687 0.9844413  0.98585573 0.97878359 0.97592068 0.98866856
#  0.97733711 0.99008499 0.99008499 0.98866856]
# Mean score : 0.9842872368985178
# standard deviation : 0.0050821819692157795
# **********************************************************

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier

X = make_classification(n_samples=1000,n_features=10,
                           n_informative=3,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           
                           random_state=42,
                        shuffle=True)


rfc = RandomForestClassifier(X,n_jobs=-1,max_features= 'auto' ,n_estimators=200, oob_score = True) 

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(x_train,training_scores_encoded)
print (CV_rfc.best_params_)
import warnings
warnings.simplefilter("ignore")
# Out:
# {'max_features': 'sqrt', 'n_estimators': 200}

# %%
rf = RandomForestClassifier(n_estimators=200,random_state=42)
rf.fit(x_train,training_scores_encoded)
predrf=rf.predict(x_test)
accu=accuracy_score(y_test,predrf)
print("accuracy score = ",accu*100)
# Out:
# accuracy score =  98.69762174405436

# %%
import pickle

filename = 'pickledrffile.pkl'
pickle.dump(rf, open(filename,'wb'))

loaded_model = pickle.load(open(filename,'rb'))

loaded_model.predict(x)
# Out:
# array([0, 0, 1, ..., 0, 1, 1])
